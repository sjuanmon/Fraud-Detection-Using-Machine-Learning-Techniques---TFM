# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from catboost import CatBoostClassifier
import numpy as np
import pandas as pd

# Cargar datos
df = pd.read_csv("Base.csv")
df.describe()
# Out:
#            fraud_bool          income  name_email_similarity  \
# count  1000000.000000  1000000.000000         1000000.000000
# mean         0.011029        0.562696               0.493694
# std          0.104438        0.290343               0.289125
# min          0.000000        0.100000               0.000001
# 25%          0.000000        0.300000               0.225216
# 50%          0.000000        0.600000               0.492153
# 75%          0.000000        0.800000               0.755567
# max          1.000000        0.900000               0.999999
#
#        prev_address_months_count  current_address_months_count  \
# count             1000000.000000                1000000.000000
# mean                   16.718568                     86.587867
# std                    44.046230                     88.406599
# min                    -1.000000                     -1.000000
# 25%                    -1.000000                     19.000000
# ...

# %%
# Convertir a categóricas
df['payment_type'] = df.payment_type.astype('category')
df['employment_status'] = df.employment_status.astype('category')
df['housing_status'] = df.housing_status.astype('category')
df['source'] = df.source.astype('category')
df['device_os'] = df.device_os.astype('category')

# %%
# One-hot encoding
df = pd.get_dummies(df, drop_first=True)

# %%
# Separar X e y
X = df.drop('fraud_bool', axis=1)
y = df['fraud_bool']

# %%
# Split train/test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# %%
# Entrenar CatBoost sin SMOTE
cat_model = CatBoostClassifier(verbose=0, random_state=42)
cat_model.fit(X_train, y_train)

# %%
# Predicciones
y_pred = cat_model.predict(X_test)

# %%
# Evaluación
print("=== CATBOOST SIN SMOTE ===")
print("Matriz de Confusión:")
print(confusion_matrix(y_test, y_pred))
print("\nReporte de Clasificación:")
print(classification_report(y_test, y_pred))
# Out:
# === CATBOOST SIN SMOTE ===
# Matriz de Confusión:
# [[296581    110]
#  [  3195    114]]
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99    296691
#            1       0.51      0.03      0.06      3309
#
#     accuracy                           0.99    300000
#    macro avg       0.75      0.52      0.53    300000
# weighted avg       0.98      0.99      0.98    300000

# %%
Observaciones:

El modelo predice casi perfectamente la clase 0 (no fraude).

Pero la clase 1 (fraude) es donde más falla: aunque tiene un recall muy bajo (0.03), la precisión es algo más decente (0.51).

Esto pasa por el desequilibrio de clases: sin SMOTE ni técnicas de balanceo, el modelo aprende a predecir mayoritariamente la clase mayoritaria (0).
